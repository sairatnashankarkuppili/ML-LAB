# %% [markdown]
# <a href="https://colab.research.google.com/github/sairatnashankarkuppili/ML-LAB/blob/main/exp3%5B25l31f0052%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/student_performance_correlation.csv")

# %%
print("Dataset Preview")
print(df.head())
# Out:
# Dataset Preview
#    StudentID  Study_Hours  Attendance_Percent  Previous_CGPA  \
# 0          1            7                  63           8.33
# 1          2            4                  61           8.07
# 2          3            8                  65           6.96
# 3          4            5                  63           7.96
# 4          5            7                  88           7.34
#
#    Assignment_Score  Lab_Score  Midterm_Score  Project_Score  Final_Score
# 0                91         94             82             90           68
# 1                91         93             53             94           55
# 2                83         72             82             92           65
# 3                71         94             63             80           55
# 4                98         55             70             91           68

# %%
print("\nStatistical Summary")
print(df.describe())
# Out:
# Statistical Summary
#        StudentID  Study_Hours  Attendance_Percent  Previous_CGPA  \
# count   50.00000    50.000000           50.000000      50.000000
# mean    25.50000     5.200000           77.960000       7.616800
# std     14.57738     2.490799           11.275692       0.927537
# min      1.00000     1.000000           60.000000       6.000000
# 25%     13.25000     3.000000           67.250000       6.862500
# 50%     25.50000     5.000000           77.000000       7.570000
# 75%     37.75000     7.000000           86.500000       8.315000
# max     50.00000     9.000000           99.000000       9.400000
#
#        Assignment_Score  Lab_Score  Midterm_Score  Project_Score  Final_Score
# count         50.000000  50.000000      50.000000      50.000000    50.000000
# mean          78.440000  77.860000      77.100000      81.320000    58.620000
# std           12.367106  12.671694      13.862665      11.014721     5.827066
# ...

# %%
correlation_matrix = df.corr()
print("\nCorrelation Matrix")
print(correlation_matrix)
# Out:
# Correlation Matrix
#                     StudentID  Study_Hours  Attendance_Percent  Previous_CGPA  \
# StudentID            1.000000    -0.139954            0.136452      -0.219808
# Study_Hours         -0.139954     1.000000           -0.118152       0.005053
# Attendance_Percent   0.136452    -0.118152            1.000000       0.034370
# Previous_CGPA       -0.219808     0.005053            0.034370       1.000000
# Assignment_Score    -0.048564     0.083875            0.069791      -0.130711
# Lab_Score            0.053197    -0.335969            0.056664      -0.070604
# Midterm_Score        0.270905    -0.294930            0.156177      -0.044685
# Project_Score       -0.182899    -0.013538           -0.221397       0.006035
# Final_Score         -0.186559     0.685894            0.137052       0.131701
#
#                     Assignment_Score  Lab_Score  Midterm_Score  Project_Score  \
# StudentID                  -0.048564   0.053197       0.270905      -0.182899
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(correlation_matrix, annot=True, cmap="magma")
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(correlation_matrix, annot=True, cmap="Blues")
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(correlation_matrix, annot=True, cmap="plasma")
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(correlation_matrix, annot=True, cmap="RdYlGn")
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(correlation_matrix, annot=True, cmap="viridis")
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(correlation_matrix, annot=True, cmap="inferno")
plt.title("Correlation Matrix Heatmap")
plt.show()
